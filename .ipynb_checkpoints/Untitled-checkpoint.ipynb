# %%
# !python naive_bayes.py
# Out:
# Traceback (most recent call last):
#   File "naive_bayes.py", line 349, in <module>
#     main()
#   File "naive_bayes.py", line 319, in main
#     matrix, levels, level_map = util.load_dataset_pooled()
# AttributeError: module 'util' has no attribute 'load_dataset_pooled'
